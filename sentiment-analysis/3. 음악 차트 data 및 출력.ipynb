# %%
import pandas as pd

# %%
music_data = [
    ['경쾌', 'How To Love (Feat. Sofia Reyes)'],
    ['경쾌', 'All For You'],
    ['경쾌', 'Living (Feat. Alex Clare)'],
    ['경쾌', 'Happy (Gru`s Theme From Despicable Me 2'],
    ['경쾌', 'Unique (Feat. Clara Mae)'],
    ['행복', 'Dream (Prod. by 박근태)'],
    ['행복', 'Love Is An Open Door'],
    ['행복', '내 손을 잡아'],
    ['행복', '200%'],
    ['행복', 'Number 1'],
    ['편안', '여자는 왜 (Feat. 옥상달빛)'],
    ['편안', 'Falling Slowly'],
    ['편안', '나의 왕자님 (My Prince)'],
    ['편안', '돌아보네'],
    ['편안', '유채꽃'],
    ['잔잔', 'Best Part (Feat. Daniel Caesar)'],
    ['잔잔', 'Moonlight'],
    ['잔잔', 'London'],
    ['잔잔', 'Walking in the Moonlight (Feat. 다원, Lazier)'],
    ['잔잔', 'Dear my blue'],
    ['우울', 'Reminiscence'],
    ['우울', 'Shelter'],
    ['우울', 'idontwannabeyouanymore'],
    ['우울', 'i hate u, i love u (Feat. olivia o`brien) (Album Ver.)'],
    ['우울', 'City Of Stars (From "La La Land" Soundtrack)'],
    ['울고싶은', '들리나요...'],
    ['울고싶은', 'My Destiny'],
    ['울고싶은', '시간을 거슬러'],
    ['울고싶은', '서쪽 하늘'],
    ['울고싶은', 'Baby, Don`t Cry (인어의 눈물)'],
    ['무서운', '잔혹동화'],
    ['무서운', '그리워 운다'],
    ['무서운', '어느 날 (Duet With 김윤아)'],
    ['무서운', '새'],
    ['무서운', '괴물'],
    ['긴장', 'Another Day'],
    ['긴장', '바꿔'],
    ['긴장', 'Burn Out'],
    ['긴장', 'Bishop`s Mes (Opening Title)'],
    ['긴장', 'Iris Main Title']
]
col = ['genre', 'title']
music_df = pd.DataFrame(music_data, columns = col)
music_df

# %%
def music_classfier(keyword):
    import pandas as pd
    
    music_data = [
    ['경쾌', 'How To Love (Feat. Sofia Reyes)'],
    ['경쾌', 'All For You'],
    ['경쾌', 'Living (Feat. Alex Clare)'],
    ['경쾌', 'Happy (Gru`s Theme From Despicable Me 2'],
    ['경쾌', 'Unique (Feat. Clara Mae)'],
    ['행복', 'Dream (Prod. by 박근태)'],
    ['행복', 'Love Is An Open Door'],
    ['행복', '내 손을 잡아'],
    ['행복', '200%'],
    ['행복', 'Number 1'],
    ['편안', '여자는 왜 (Feat. 옥상달빛)'],
    ['편안', 'Falling Slowly'],
    ['편안', '나의 왕자님 (My Prince)'],
    ['편안', '돌아보네'],
    ['편안', '유채꽃'],
    ['잔잔', 'Best Part (Feat. Daniel Caesar)'],
    ['잔잔', 'Moonlight'],
    ['잔잔', 'London'],
    ['잔잔', 'Walking in the Moonlight (Feat. 다원, Lazier)'],
    ['잔잔', 'Dear my blue'],
    ['우울', 'Reminiscence'],
    ['우울', 'Shelter'],
    ['우울', 'idontwannabeyouanymore'],
    ['우울', 'i hate u, i love u (Feat. olivia o`brien) (Album Ver.)'],
    ['우울', 'City Of Stars (From "La La Land" Soundtrack)'],
    ['울고싶은', '들리나요...'],
    ['울고싶은', 'My Destiny'],
    ['울고싶은', '시간을 거슬러'],
    ['울고싶은', '서쪽 하늘'],
    ['울고싶은', 'Baby, Don`t Cry (인어의 눈물)'],
    ['무서운', '잔혹동화'],
    ['무서운', '그리워 운다'],
    ['무서운', '어느 날 (Duet With 김윤아)'],
    ['무서운', '새'],
    ['무서운', '괴물'],
    ['긴장', 'Another Day'],
    ['긴장', '바꿔'],
    ['긴장', 'Burn Out'],
    ['긴장', 'Bishop`s Mes (Opening Title)'],
    ['긴장', 'Iris Main Title']
    ]
    col = ['genre', 'title']
    music_df = pd.DataFrame(music_data, columns = col)

    genre = {'기쁨':'경쾌',
             '신뢰':'편안',
            '공포':'무서운',
            '기대':'행복',
            '놀라움':'긴장',
            '슬픔':'우울',
            '혐오':'무서운',
            '분노':'울고싶은'}
    
    key = genre[keyword]
    
    dic_len = len(music_df[music_df['genre']==key])
    music_list = []
    
    for index in range (dic_len) : 
        title = music_df[music_df['genre']==key]['title'].values[index]
        music_list.append(title)

    for songs in music_list : 
        print(songs)
